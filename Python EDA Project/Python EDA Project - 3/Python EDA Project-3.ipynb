# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm #for data normilization
#from sklearn.preprocessing import StandardScaler #for standarise the data 
from scipy import stats
plt.style.use('ggplot')
#pd.set_option('max_columns',200)

# %%
df = pd.read_csv('coaster_db.csv')

# %%
df.shape # to show shape of the column
# Out:
# (1087, 56)

# %%
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# 0  LaMarcus Adna Thompson                NaN  Lift Packed  ...  6 mph
# 1            Lina Beecher                NaN          NaN  ...     NaN
# 2                     NaN                NaN          NaN  ...     NaN
# 3          Edwin Prescott                NaN          NaN  ...     NaN
# 4          Edwin Prescott                NaN          NaN  ...     NaN
#
#      speed2 speed1_value speed1_unit speed_mph height_value height_unit  \
# 0  9.7 km/h          6.0         mph       6.0         50.0          ft
# 1       NaN          NaN         NaN       NaN          NaN         NaN
# 2       NaN          NaN         NaN       NaN          NaN         NaN
# 3       NaN          NaN         NaN       NaN          NaN         NaN
# 4       NaN          NaN         NaN       NaN          NaN         NaN
#
#   height_ft Inversions_clean Gforce_clean
# 0       NaN                0          2.9
# 1       NaN                1         12.0
# 2       NaN                0          NaN
# 3       NaN                1          NaN
# 4       NaN                1          NaN
#
# [5 rows x 56 columns]

# %%
df.columns # to show all column names
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df.dtypes #t0o show data types of the columns
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# Fast Lane available               object
# Replaced                          object
# Track layout                      object
# Fastrack available                object
# Soft opening date.1               object
# Closing date                      object
# Opened                            object
# Replaced by                       object
# Website                           object
# Flash Pass Available              object
# Must transfer from wheelchair     object
# Theme                             object
# Single rider line available       object
# Restraint Style                   object
# Flash Pass available              object
# Acceleration                      object
# Restraints                        object
# Name                              object
# year_introduced                    int64
# latitude                         float64
# longitude                        float64
# Type_Main                         object
# opening_date_clean                object
# speed1                            object
# speed2                            object
# speed1_value                     float64
# speed1_unit                       object
# speed_mph                        float64
# height_value                     float64
# height_unit                       object
# height_ft                        float64
# Inversions_clean                   int64
# Gforce_clean                     float64
# dtype: object

# %%
df.describe() #shows statical information of the nurmecal data in the data frame
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# min      5.000000      4.000000   13.100000          0.000000      0.800000
# 25%     37.300000     44.000000   51.800000          0.000000      3.400000
# 50%     49.700000     79.000000   91.200000          0.000000      4.000000
# 75%     58.000000    113.000000  131.200000          2.000000      4.500000
# max    149.100000   3937.000000  377.300000         14.000000     12.000000

# %% [markdown]
# # data preperation

# %%
# removing unwanted columns

# %%
#type 1

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df_clean = df[['coaster_name', 
    #'Length', 'Speed', 
    'Location', 
    #'Status', 
    'Opening date',
      # 'Type', 
    'Manufacturer', 
    #'Height restriction', 'Model', 'Height',
     #  'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
      # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
    #   'Closing date', 
    'Opened', 
    #'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',   
    'speed_mph',
    # 'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']]

# %%
df_clean
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
#        Opening date                 Manufacturer Opened  year_introduced  \
# 0     June 16, 1884       LaMarcus Adna Thompson    NaN             1884
# 1              1895                 Lina Beecher    NaN             1895
# 2               NaN                          NaN   1895             1896
# 3              1901               Edwin Prescott    NaN             1901
# 4              1901               Edwin Prescott    NaN             1901
# ...             ...                          ...    ...              ...
# 1082            NaN            Anton Schwarzkopf    NaN             2022
# 1083           2022                      Intamin    NaN             2022
# 1084  June 16, 2016                       Vekoma    NaN             2022
# 1085            NaN    S&S – Sansei Technologies    NaN             2022
# 1086           2022  Rocky Mountain Construction    NaN             2022
#
#       latitude  longitude Type_Main opening_date_clean  speed_mph  height_ft  \
# 0      40.5740   -73.9780      Wood         1884-06-16        6.0        NaN
# 1      40.5780   -73.9790      Wood         1895-01-01        NaN        NaN
# 2      41.5800   -81.5700     Other                NaN        NaN        NaN
# 3      40.5745   -73.9780     Steel         1901-01-01        NaN        NaN
# 4      39.3538   -74.4342     Steel         1901-01-01        NaN        NaN
# ...        ...        ...       ...                ...        ...        ...
# 1082       NaN        NaN     Steel                NaN       53.0        NaN
# 1083   37.2339   -76.6426     Steel         2022-01-01       73.0        NaN
# 1084       NaN        NaN     Steel         2016-06-16       59.3        NaN
# 1085       NaN        NaN     Steel                NaN       34.0        NaN
# 1086       NaN        NaN     Steel         2022-01-01       58.0        NaN
#
#       Inversions_clean  Gforce_clean
# 0                    0           2.9
# 1                    1          12.0
# 2                    0           NaN
# 3                    1           NaN
# 4                    1           NaN
# ...                ...           ...
# 1082                 3           4.7
# 1083                 2           NaN
# 1084                 0           4.0
# 1085                 0           NaN
# 1086                 3           NaN
#
# [1087 rows x 14 columns]

# %%
#type 2

# %%
# df2=df.drop(['Opening date'],axis=1)

# %%
df = df_clean

# %%
df.shape
# Out:
# (1087, 14)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Opening date           object
# Manufacturer           object
# Opened                 object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
#to change data type of the columns

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
df.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Opening date                  object
# Manufacturer                  object
# Opened                        object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_ft                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
#to rename columns

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
# example1 df.rename(columns={'coaster_name' = 'Coaster_Name'})

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
LON = list(df)

# %%
LNN = [L.capitalize() for L in LON]

# %%
LNN
# Out:
# ['Coaster_name',
#  'Location',
#  'Opening_date',
#  'Manufacturer',
#  'Opened',
#  'Year_introduced',
#  'Latitude',
#  'Longitude',
#  'Type_main',
#  'Opening_date_clean',
#  'Speed_mph',
#  'Height_ft',
#  'Inversions_clean',
#  'Gforce_clean']

# %%
dit = res = dict(zip(LON, LNN))

# %%
df = df.rename(columns=dit) #changing column name

# %%
df
# Out:
#                                 Coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
#        Opening_date                 Manufacturer Opened  Year_introduced  \
# 0     June 16, 1884       LaMarcus Adna Thompson    NaN             1884
# 1              1895                 Lina Beecher    NaN             1895
# 2               NaN                          NaN   1895             1896
# 3              1901               Edwin Prescott    NaN             1901
# 4              1901               Edwin Prescott    NaN             1901
# ...             ...                          ...    ...              ...
# 1082            NaN            Anton Schwarzkopf    NaN             2022
# 1083           2022                      Intamin    NaN             2022
# 1084  June 16, 2016                       Vekoma    NaN             2022
# 1085            NaN    S&S – Sansei Technologies    NaN             2022
# 1086           2022  Rocky Mountain Construction    NaN             2022
#
#       Latitude  Longitude Type_main Opening_date_clean  Speed_mph  Height_ft  \
# 0      40.5740   -73.9780      Wood         1884-06-16        6.0        NaN
# 1      40.5780   -73.9790      Wood         1895-01-01        NaN        NaN
# 2      41.5800   -81.5700     Other                NaT        NaN        NaN
# 3      40.5745   -73.9780     Steel         1901-01-01        NaN        NaN
# 4      39.3538   -74.4342     Steel         1901-01-01        NaN        NaN
# ...        ...        ...       ...                ...        ...        ...
# 1082       NaN        NaN     Steel                NaT       53.0        NaN
# 1083   37.2339   -76.6426     Steel         2022-01-01       73.0        NaN
# 1084       NaN        NaN     Steel         2016-06-16       59.3        NaN
# 1085       NaN        NaN     Steel                NaT       34.0        NaN
# 1086       NaN        NaN     Steel         2022-01-01       58.0        NaN
#
#       Inversions_clean  Gforce_clean
# 0                    0           2.9
# 1                    1          12.0
# 2                    0           NaN
# 3                    1           NaN
# 4                    1           NaN
# ...                ...           ...
# 1082                 3           4.7
# 1083                 2           NaN
# 1084                 0           4.0
# 1085                 0           NaN
# 1086                 3           NaN
#
# [1087 rows x 14 columns]

# %%
#to find null values

# %%
df.isna()
# Out:
#       Coaster_name  Location  Opening_date  Manufacturer  Opened  \
# 0            False     False         False         False    True
# 1            False     False         False         False    True
# 2            False     False          True          True   False
# 3            False     False         False         False    True
# 4            False     False         False         False    True
# ...            ...       ...           ...           ...     ...
# 1082         False     False          True         False    True
# 1083         False     False         False         False    True
# 1084         False     False         False         False    True
# 1085         False     False          True         False    True
# 1086         False     False         False         False    True
#
#       Year_introduced  Latitude  Longitude  Type_main  Opening_date_clean  \
# 0               False     False      False      False               False
# 1               False     False      False      False               False
# 2               False     False      False      False                True
# 3               False     False      False      False               False
# 4               False     False      False      False               False
# ...               ...       ...        ...        ...                 ...
# 1082            False      True       True      False                True
# 1083            False     False      False      False               False
# 1084            False      True       True      False               False
# 1085            False      True       True      False                True
# 1086            False      True       True      False               False
#
#       Speed_mph  Height_ft  Inversions_clean  Gforce_clean
# 0         False       True             False         False
# 1          True       True             False         False
# 2          True       True             False          True
# 3          True       True             False          True
# 4          True       True             False          True
# ...         ...        ...               ...           ...
# 1082      False       True             False         False
# 1083      False       True             False          True
# 1084      False       True             False         False
# 1085      False       True             False          True
# 1086      False       True             False          True
#
# [1087 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# Coaster_name             0
# Location                 0
# Opening_date           250
# Manufacturer            59
# Opened                1060
# Year_introduced          0
# Latitude               275
# Longitude              275
# Type_main                0
# Opening_date_clean     250
# Speed_mph              150
# Height_ft              916
# Inversions_clean         0
# Gforce_clean           725
# dtype: int64

# %%
#to find Dupilcate data 
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_name, Location, Opening_date, Manufacturer, Opened, Year_introduced, Latitude, Longitude, Type_main, Opening_date_clean, Speed_mph, Height_ft, Inversions_clean, Gforce_clean]
# Index: []

# %%
#duplicated in coluns (subset)

# %%
df.duplicated(subset=['Coaster_name'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated(subset=['Coaster_name'])]
# Out:
#                             Coaster_name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                                            Opening_date  \
# 43                                                 1926
# 60                                                 1911
# 61                                         May 23, 1938
# 167                                                 NaN
# 237   May 23, 1981 as Blauer Enzian, 1986 as Thunder...
# ...                                                 ...
# 1063  1999 as Road Runner Railway; 2021 as Lil' Devi...
# 1064                                              1950s
# 1080                                                NaN
# 1082                                                NaN
# 1084                                      June 16, 2016
#
#                                            Manufacturer Opened  \
# 43                                   Traver Engineering    NaN
# 60                                       Fred W. Pearce    NaN
# 61                                                  NaN    NaN
# 167   Arrow Development (California and Florida)Dyna...    NaN
# 237                                          Mack Rides    NaN
# ...                                                 ...    ...
# 1063                                           Zamperla    NaN
# 1064                            Allan Herschell Company    NaN
# 1080                        Rocky Mountain Construction    NaN
# 1082                                  Anton Schwarzkopf    NaN
# 1084                                             Vekoma    NaN
#
#       Year_introduced  Latitude  Longitude Type_main Opening_date_clean  \
# 43               1927   42.8617   -79.0598      Wood         1926-01-01
# 60               1937   42.4200   -70.9860      Wood         1911-01-01
# 61               1938   41.6349   -80.3180      Wood         1938-05-23
# 167              1980       NaN        NaN     Steel                NaT
# 237              1986   43.8427   -79.5423     Steel         1981-05-23
# ...               ...       ...        ...       ...                ...
# 1063             2021   40.1343   -74.4434     Steel         1999-01-01
# 1064             2021   41.6343   -80.3165     Steel         1950-01-01
# 1080             2022   28.0339   -82.4231     Steel                NaT
# 1082             2022       NaN        NaN     Steel                NaT
# 1084             2022       NaN        NaN     Steel         2016-06-16
#
#       Speed_mph  Height_ft  Inversions_clean  Gforce_clean
# 43         60.0        NaN                 0           4.0
# 60          NaN        NaN                 0           NaN
# 61         50.0        NaN                 0           NaN
# 167        35.0        NaN                 0           NaN
# 237        39.8       32.8                 0           NaN
# ...         ...        ...               ...           ...
# 1063        NaN        NaN                 0           NaN
# 1064        NaN        NaN                 0           NaN
# 1080       76.0        NaN                 2           NaN
# 1082       53.0        NaN                 3           4.7
# 1084       59.3        NaN                 0           4.0
#
# [97 rows x 14 columns]

# %%
# example to find the element that is duplicated

# %%
df.query('Coaster_name =="American Dreier Looping"')
# Out:
#                  Coaster_name Location Opening_date       Manufacturer Opened  \
# 422   American Dreier Looping    Other          NaN  Anton Schwarzkopf    NaN
# 686   American Dreier Looping    Other          NaN  Anton Schwarzkopf    NaN
# 738   American Dreier Looping    Other          NaN  Anton Schwarzkopf    NaN
# 1082  American Dreier Looping    Other          NaN  Anton Schwarzkopf    NaN
#
#       Year_introduced  Latitude  Longitude Type_main Opening_date_clean  \
# 422              1997       NaN        NaN     Steel                NaT
# 686              2005       NaN        NaN     Steel                NaT
# 738              2007       NaN        NaN     Steel                NaT
# 1082             2022       NaN        NaN     Steel                NaT
#
#       Speed_mph  Height_ft  Inversions_clean  Gforce_clean
# 422        53.0        NaN                 3           4.7
# 686        53.0        NaN                 3           4.7
# 738        53.0        NaN                 3           4.7
# 1082       53.0        NaN                 3           4.7

# %%
#remove duplicate

# %%
#to find first instanct of the record

# %%
df = df.sort_values(by='Year_introduced', ascending=True)

# %%
df
# Out:
#                                 Coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1073                           ArieForce One        Fun Spot America Atlanta
# 1072                     Aquaman: Power Wave            Six Flags Over Texas
# 1085                                 Tumbili                  Kings Dominion
# 1078  Guardians of the Galaxy: Cosmic Rewind                           Epcot
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
#        Opening_date                 Manufacturer Opened  Year_introduced  \
# 0     June 16, 1884       LaMarcus Adna Thompson    NaN             1884
# 1              1895                 Lina Beecher    NaN             1895
# 2               NaN                          NaN   1895             1896
# 3              1901               Edwin Prescott    NaN             1901
# 4              1901               Edwin Prescott    NaN             1901
# ...             ...                          ...    ...              ...
# 1073           2022  Rocky Mountain Construction    NaN             2022
# 1072        2022[1]                   Mack Rides    NaN             2022
# 1085            NaN    S&S – Sansei Technologies    NaN             2022
# 1078           2022                       Vekoma    NaN             2022
# 1086           2022  Rocky Mountain Construction    NaN             2022
#
#       Latitude  Longitude Type_main Opening_date_clean  Speed_mph  Height_ft  \
# 0      40.5740   -73.9780      Wood         1884-06-16        6.0        NaN
# 1      40.5780   -73.9790      Wood         1895-01-01        NaN        NaN
# 2      41.5800   -81.5700     Other                NaT        NaN        NaN
# 3      40.5745   -73.9780     Steel         1901-01-01        NaN        NaN
# 4      39.3538   -74.4342     Steel         1901-01-01        NaN        NaN
# ...        ...        ...       ...                ...        ...        ...
# 1073       NaN        NaN     Steel         2022-01-01       64.0        NaN
# 1072   32.7560   -97.0710     Steel         2022-01-01       62.1        NaN
# 1085       NaN        NaN     Steel                NaT       34.0        NaN
# 1078       NaN        NaN     Steel         2022-01-01        NaN        NaN
# 1086       NaN        NaN     Steel         2022-01-01       58.0        NaN
#
#       Inversions_clean  Gforce_clean
# 0                    0          2.90
# 1                    1         12.00
# 2                    0           NaN
# 3                    1           NaN
# 4                    1           NaN
# ...                ...           ...
# 1073                 4          3.75
# 1072                 0           NaN
# 1085                 0           NaN
# 1078                 0           NaN
# 1086                 3           NaN
#
# [1087 rows x 14 columns]

# %%
~df.duplicated(subset=['Coaster_name','Location','Opening_date'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1073    True
# 1072    True
# 1085    True
# 1078    True
# 1086    True
# Length: 1087, dtype: bool

# %%
df = df.loc[~df.duplicated(subset=['Coaster_name','Location','Opening_date'])].reset_index(drop=True)

# %%
df
# Out:
#                                Coaster_name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985                           ArieForce One        Fun Spot America Atlanta
# 986                     Aquaman: Power Wave            Six Flags Over Texas
# 987                                 Tumbili                  Kings Dominion
# 988  Guardians of the Galaxy: Cosmic Rewind                           Epcot
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
#       Opening_date                 Manufacturer Opened  Year_introduced  \
# 0    June 16, 1884       LaMarcus Adna Thompson    NaN             1884
# 1             1895                 Lina Beecher    NaN             1895
# 2              NaN                          NaN   1895             1896
# 3             1901               Edwin Prescott    NaN             1901
# 4             1901               Edwin Prescott    NaN             1901
# ..             ...                          ...    ...              ...
# 985           2022  Rocky Mountain Construction    NaN             2022
# 986        2022[1]                   Mack Rides    NaN             2022
# 987            NaN    S&S – Sansei Technologies    NaN             2022
# 988           2022                       Vekoma    NaN             2022
# 989           2022  Rocky Mountain Construction    NaN             2022
#
#      Latitude  Longitude Type_main Opening_date_clean  Speed_mph  Height_ft  \
# 0     40.5740   -73.9780      Wood         1884-06-16        6.0        NaN
# 1     40.5780   -73.9790      Wood         1895-01-01        NaN        NaN
# 2     41.5800   -81.5700     Other                NaT        NaN        NaN
# 3     40.5745   -73.9780     Steel         1901-01-01        NaN        NaN
# 4     39.3538   -74.4342     Steel         1901-01-01        NaN        NaN
# ..        ...        ...       ...                ...        ...        ...
# 985       NaN        NaN     Steel         2022-01-01       64.0        NaN
# 986   32.7560   -97.0710     Steel         2022-01-01       62.1        NaN
# 987       NaN        NaN     Steel                NaT       34.0        NaN
# 988       NaN        NaN     Steel         2022-01-01        NaN        NaN
# 989       NaN        NaN     Steel         2022-01-01       58.0        NaN
#
#      Inversions_clean  Gforce_clean
# 0                   0          2.90
# 1                   1         12.00
# 2                   0           NaN
# 3                   1           NaN
# 4                   1           NaN
# ..                ...           ...
# 985                 4          3.75
# 986                 0           NaN
# 987                 0           NaN
# 988                 0           NaN
# 989                 3           NaN
#
# [990 rows x 14 columns]

# %% [markdown]
# # Analysis

# %%
df['Year_introduced'].value_counts()
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: Year_introduced, Length: 101, dtype: int64

# %%
#Top 10 Years Coaster Introduced

# %%
ax = df['Year_introduced'].value_counts().head(10).plot(kind='bar', title='Top 10 Years Coaster Introduced')
ax.set_xlabel('Years Introduced')
ax.set_ylabel('Count')
plt.show()

# %%
#Coaster Speed distribution

# %%
ax = df['Speed_mph'].plot(kind='kde',title='Coaster Speed (MpH)')

# %%
#Speed Vs Hight

# %%
ax = df.plot(kind='scatter',x='Speed_mph',y='Height_ft',title='Coaster Speed vs Hight')

# %%
#using Seaborn
ax = sns.scatterplot(x='Speed_mph',y='Height_ft',data=df,hue='Type_main')

# %%
#pair plots used to compare multiple fields

# %%
aa = sns.pairplot(df,vars=['Year_introduced','Height_ft','Speed_mph'],hue = 'Type_main')

# %%
#Correlation

# %%
df_corr = df[['Year_introduced','Speed_mph',
    'Height_ft','Inversions_clean','Gforce_clean']].dropna().corr()

# %%
sns.heatmap(df_corr, annot=True)
plt.show()

# %%
#Avg coaster speed by location
df.query('Location != "Other"').groupby('Location')['Speed_mph'].agg(['mean','count']).query('count >= 10').sort_values('mean',ascending=False)['mean'].plot(kind='barh')
plt.show()
